# %% [markdown]
# # Dictionaries
#
# To submit this assignment in D2l, post the link to your notebook file on your GitHub account.

# %% [markdown]
# ## 12.1 Champion Counter
# Create a program that reads a text file that contains a list of FIFA World Cup champions and determines the country that has won the most championships.
#
# ### Console:
# ```powershell
# Country	        Wins	Years
# =======	        ====	=====
# Argentina       2       1978, 1986
# Brazil	        5       1958, 1962, 1970, 1994, 2002
# England	        1       1966
# France	        1       1998
# Germany	        4       1954, 1974, 1990, 2014
# Italy	        4       1934, 1938, 1982, 2006
# Spain	        1       2010
# Uruguay	        2       1930, 1950
# ```
#
# ### Specifications:
# - Use the attached text file named `world_cup_champions.txt` that contains data like this:
# ```powershell
# Year,Country,Coach,Captain
# 1930,Uruguay,Alberto Suppici,José Nasazzi
# 1934,Italy,Vittorio Pozzo,Gianpiero Combi
# 1938,Italy,Vittorio Pozzo,Giuseppe Meazza
# ...
# ```
# - When the program starts, it should read the text file and use a dictionary to store the required data using the name of each country that has won the World Cup as the key.
# - The program should compile the data shown above and display the countries alphabetically.

# %%
file = open("world_cup_champions.txt", 'r')
champs = file.read()
champs = champs.replace("\n",",")
#print(champs)
champs = champs.split(',')

champs2 = []
index=0 
data={}

for i in range(int(len(champs)/4)):     #loop to turn list into a 2d list to make it easier to work with
    temp = []
    for x in range(4):
        temp.append(champs[index])
        index+=1
    champs2.append(temp) #2d champs list

for layer in champs2:
    team = layer[1]
    year = layer[0]
    
    if team in data:
        data[team]["wins"]+=1
        data[team]["years"].append(year)
    else:
        data[team] = {"wins": 1, "years": [year]}

data.pop("Country")  

sorted_teams = sorted(data.items(), key=lambda x: x[1]["wins"], reverse=True)
print("Team        Wins   Years")
print("====        ====   =====")
for team, info in sorted_teams:
    print(f"{team:<12}{info['wins']:<7}{info['years']}")

# %% [markdown]
# ## 12.2 Monthly Sales
# Create a program that allows you to view and edit the sales amounts for each month of the current year.
#
# ### Console:
# ```powershell
# Monthly Sales program
#
# COMMAND MENU
# view	- View sales for specified month
# edit	- Edit sales for specified month
# totals - View sales summary for year
# exit	- Exit program
#
# Command: view
# Three-letter Month: jan
# Sales amount for Jan is 14,317.00.
#
# Command: edit
# Three-letter Month: jan
# Sales Amount: 15293
# Sales amount for Jan is 15,293.00.
#
# Command: totals
# Yearly total: 67,855.00
# Monthly average: 5,654.58
#
# Command: view
# Three-letter Month: july
# Invalid three-letter month.
#
# Command: exit Bye!
# ```
#
# ### Specifications:
# - Use the attached text file named `monthly_sales.txt` that consists of rows that contain three-letter abbreviations for the month and the monthly sales.
# - The program should read the file and store the sales data for each month in a dictionary with the month abbreviation as the key for each item.
# - Whenever the sales data is edited, the program should write the changed data to the text file.

# %%
def commands():
    print("COMMAND MENU")
    print("view   -View sales for specified month")
    print("edit   - Edit sales for a specified month")
    print("totals - View sales summary for year")
    print("exit   - Exit program")
file = open("monthly_sales.txt", "r")
data = file.read()
data = data.replace("\n","\t")
data = data.split("\t")
sales = {}
for i in range(0,len(data)-2,2): #turning data into sales dictonary
    month = data[i]
    income = int(data[i+1])
    sales[month]=income
#print(sales)
done = False
changed = False
while not done:
    commands()
    user_input = input("Command: ")
    print()
    if user_input == "view":
        user_input = input("Three-letter month: ")
        print(f"Sales amount for {user_input} is {sales[user_input]}")
        print()
    elif user_input == "edit":
        user_input = input("Three-letter month: ")
        new_amount = int(input("Sales Amount: "))
        sales[user_input] = new_amount
        changed = True
        print(f"Sales amount for {user_input} is {sales[user_input]}")
        print()
    elif user_input == "totals":
        total = 0
        for i in sales.values():
            total += i
        average = total/len(sales.values())
        print(f"Yearly total: {total} \nMonthly average: {average}\n")
       
    elif user_input == "exit":
        done =True
        print("Bye!")
    else:
        print("Invalid command, please try again \n")
#print(sales)
if changed:  #updates file if anything was changed
    file = open("monthly_sales.txt", "w")
    for key, value in sales.items():
        file.write(f"{key}\t{value}\n")
    
    file.close()
